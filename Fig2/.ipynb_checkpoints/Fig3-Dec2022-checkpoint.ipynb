# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as tck

fig, axs = plt.subplots(2, 3)

#-----for nu=0, csfb and bac
csfb0=[(0, 0.544967),(1, 1.28428),(2, 2.2768),(3, 3.45492),(4, 4.73832),(5, 6.03956),(6, 7.26995),(7, 8.34565),(8, 9.19335),(9, 9.75528),(10, 9.99315),(11, 9.89074),(12, 9.45503),(13, 8.71572),(14, 7.7232),(15, 6.54508),(16, 5.26168),(17, 3.96044),(18, 2.73005),(19, 1.65435),(20, 0.806647),(21, 0.244717),(22, 0.00685233),(23, 0.109262),(24, 0.544967),(25, 1.28428),(26, 2.2768),(27, 3.45492),(28, 4.73832),(29, 6.03956),(30, 7.26995),(31, 8.34565),(32, 9.19335),(33, 9.75528),(34, 9.99315),(35, 9.89074),(36, 9.45503),(37, 8.71572),(38, 7.7232),(39, 6.54508),(40, 5.26168),(41, 3.96044),(42, 2.73005),(43, 1.65435),(44, 0.806647),(45, 0.244717),(46, 0.00685233),(47, 0.109262),(48, 0.544967)]
bac0=[(0., 0.867325),(0.25, 0.692431),(0.5, 0.544074),(0.75, 0.4199),(1., 0.317555),(1.25, 0.234684),(1.5, 0.168932),(1.75, 0.117945),(2., 0.0793685),(2.25, 0.0469169),(2.5, 0.0237395),(2.75, 0.00905414),(3., 0.00207896),(3.25, -0.00136783),(3.5, 0.00269151),(3.75, 0.0148349),(4., 0.0356404),(4.25, 0.0616982),(4.5, 0.099169),(4.75, 0.150226),(5., 0.217041),(5.25, 0.297169),(5.5, 0.39925),(5.75, 0.527304),(6., 0.685354),(6.25, 0.876454),(6.5, 1.10598),(6.75, 1.37833),(7., 1.69792),(7.25, 2.08179),(7.5, 2.51666),(7.75, 3.00187),(8., 3.53679),(8.25, 4.15055),(8.5, 4.80081),(8.75, 5.47499),(9., 6.16055),(9.25, 6.86686),(9.5, 7.55064),(9.75, 8.19053),(10., 8.76519),(10.25, 9.23019),(10.5, 9.59649),(10.75, 9.852),(11., 9.98459),(11.25, 9.92714),(11.5, 9.74456),(11.75, 9.44672),(12., 9.04353),(12.25, 8.51688),(12.5, 7.91584),(12.75, 7.26151),(13., 6.57497),(13.25, 5.89554),(13.5, 5.21878),(13.75, 4.5585),(14., 3.92849),(14.25, 3.37247),(14.5, 2.86234),(14.75, 2.39992),(15., 1.98704),(15.25, 1.63991),(15.5, 1.3402),(15.75, 1.08399),(16., 0.867325),(16.25, 0.686543),(16.5, 0.537345),(16.75, 0.415694),(17., 0.317555),(17.25, 0.234684),(17.5, 0.168932),(17.75, 0.117945),(18., 0.0793685),(18.25, 0.0469169),(18.5, 0.0237395),(18.75, 0.00905414),(19., 0.00207896),(19.25, -0.00136783),(19.5, 0.00269151),(19.75, 0.0148349),(20., 0.0356404),(20.25, 0.0616982),(20.5, 0.099169),(20.75, 0.150226),(21., 0.217041),(21.25, 0.297169),(21.5, 0.39925),(21.75, 0.527304),(22., 0.685354),(22.25, 0.876454),(22.5, 1.10598),(22.75, 1.37833),(23., 1.69792),(23.25, 2.08179),(23.5, 2.51666),(23.75, 3.00187),(24., 3.53679),(24.25, 4.15055),(24.5, 4.80081),(24.75, 5.47499),(25., 6.16055),(25.25, 6.86686),(25.5, 7.55064),(25.75, 8.19053),(26., 8.76519),(26.25, 9.23019),(26.5, 9.59649),(26.75, 9.852),(27., 9.98459),(27.25, 9.92714),(27.5, 9.74456),(27.75, 9.44672),(28., 9.04353),(28.25, 8.51688),(28.5, 7.91584),(28.75, 7.26151),(29., 6.57497),(29.25, 5.89554),(29.5, 5.21878),(29.75, 4.5585),(30., 3.92849),(30.25, 3.37247),(30.5, 2.86234),(30.75, 2.39992),(31., 1.98704),(31.25, 1.63991),(31.5, 1.3402),(31.75, 1.08399),(32., 0.867325),(32.25, 0.686543),(32.5, 0.537345),(32.75, 0.415694),(33., 0.317555),(33.25, 0.234684),(33.5, 0.168932),(33.75, 0.117945),(34., 0.0793685),(34.25, 0.0469169),(34.5, 0.0237395),(34.75, 0.00905414),(35., 0.00207896),(35.25, -0.00136783),(35.5, 0.00269151),(35.75, 0.0148349),(36., 0.0356404),(36.25, 0.0616982),(36.5, 0.099169),(36.75, 0.150226),(37., 0.217041),(37.25, 0.297169),(37.5, 0.39925),(37.75, 0.527304),(38., 0.685354),(38.25, 0.876454),(38.5, 1.10598),(38.75, 1.37833),(39., 1.69792),(39.25, 2.08179),(39.5, 2.51666),(39.75, 3.00187),(40., 3.53679),(40.25, 4.15055),(40.5, 4.80081),(40.75, 5.47499),(41., 6.16055),(41.25, 6.86686),(41.5, 7.55064),(41.75, 8.19053),(42., 8.76519),(42.25, 9.23019),(42.5, 9.59649),(42.75, 9.852),(43., 9.98459),(43.25, 9.92714),(43.5, 9.74456),(43.75, 9.44672),(44., 9.04353),(44.25, 8.51688),(44.5, 7.91584),(44.75, 7.26151),(45., 6.57497),(45.25, 5.89554),(45.5, 5.21878),(45.75, 4.5585),(46., 3.92849),(46.25, 3.34254),(46.5, 2.81445),(46.75, 2.35802),(47., 1.98704),(47.25, 1.71531),(47.5, 1.55662),(47.75, 1.52477),(48., 1.63355)]
xC0, yC0 = zip(*csfb0)
xB0, yB0 = zip(*bac0)
axs[0,0].plot(xC0,yC0,color='green')
axs[0,0].plot(xB0,yB0,color='red')
axs[0,0].fill_between(xB0, yB0, alpha=0.2,color='red')
axs[0,0].set_xlim(0, 48)
axs[0,0].set_xticks([0,12,24,36,48])
axs[0,0].set_ylim(0, 12)
axs[0,0].set_yticks([0,2,4,6,8,10,12])
axs[0,0].yaxis.set_minor_locator(tck.AutoMinorLocator())
axs[0,0].xaxis.set_minor_locator(tck.AutoMinorLocator())
axs[0, 0].set_title(r'$\nu=0$')
axs[0,0].set_ylabel('Local Concentrations')


#-----for nu=0.5, csfb and bac
csfb05=[(0, 0.544967),(1, 1.28428),(2, 2.2768),(3, 3.45492),(4, 4.73832),(5, 6.03956),(6, 7.26995),(7, 8.34565),(8, 9.19335),(9, 9.75528),(10, 9.99315),(11, 9.89074),(12, 9.45503),(13, 8.71572),(14, 7.7232),(15, 6.54508),(16, 5.26168),(17, 3.96044),(18, 2.73005),(19, 1.65435),(20, 0.806647),(21, 0.244717),(22, 0.00685233),(23, 0.109262),(24, 0.544967),(25, 1.28428),(26, 2.2768),(27, 3.45492),(28, 4.73832),(29, 6.03956),(30, 7.26995),(31, 8.34565),(32, 9.19335),(33, 9.75528),(34, 9.99315),(35, 9.89074),(36, 9.45503),(37, 8.71572),(38, 7.7232),(39, 6.54508),(40, 5.26168),(41, 3.96044),(42, 2.73005),(43, 1.65435),(44, 0.806647),(45, 0.244717),(46, 0.00685233),(47, 0.109262),(48, 0.544967)]
bac05=[(0, 1.06916),(1, 0.497156),(2, 0.153193),(3, 0.00464711),(4, 0.0845516),(5, 0.495121),(6, 1.36882),(7, 2.76044),(8, 4.49954),(9, 6.13493),(10, 7.10446),(11, 7.06359),(12, 6.09962),(13, 4.63897),(14, 3.15493),(15, 1.93942),(16, 1.06916),(17, 0.497156),(18, 0.153193),(19, 0.00464711),(20, 0.0845516),(21, 0.495121),(22, 1.36882),(23, 2.76044),(24, 4.49954),(25, 6.13493),(26, 7.10446),(27, 7.06359),(28, 6.09962),(29, 4.63897),(30, 3.15493),(31, 1.93942),(32, 1.06916),(33, 0.497156),(34, 0.153193),(35, 0.00464711),(36, 0.0845516),(37, 0.495121),(38, 1.36882),(39, 2.76044),(40, 4.49954),(41, 6.13493),(42, 7.10446),(43, 7.06359),(44, 6.09962),(45, 4.63897),(46, 3.15493),(47, 1.93942),(48, 1.28434)]
xC05, yC05 = zip(*csfb05)
xB05, yB05 = zip(*bac05)
axs[0,1].plot(xC05,yC05,color='green')
axs[0,1].plot(xB05,yB05,color='red')
axs[0,1].fill_between(xB05, yB05, alpha=0.2,color='red')
axs[0,1].set_xlim(0, 48)
axs[0,1].set_xticks([0,12,24,36,48])
axs[0,1].set_ylim(0, 12)
axs[0,1].set_yticks([0,2,4,6,8,10,12])
axs[0,1].yaxis.set_minor_locator(tck.AutoMinorLocator())
axs[0,1].xaxis.set_minor_locator(tck.AutoMinorLocator())
axs[0,1].set_title(r'$\nu=0.5$')

#-----for nu=1 csfb and bac
csfb1=[(0, 0.544967),(1, 1.28428),(2, 2.2768),(3, 3.45492),(4, 4.73832),(5, 6.03956),(6, 7.26995),(7, 8.34565),(8, 9.19335),(9, 9.75528),(10, 9.99315),(11, 9.89074),(12, 9.45503),(13, 8.71572),(14, 7.7232),(15, 6.54508),(16, 5.26168),(17, 3.96044),(18, 2.73005),(19, 1.65435),(20, 0.806647),(21, 0.244717),(22, 0.00685233),(23, 0.109262),(24, 0.544967),(25, 1.28428),(26, 2.2768),(27, 3.45492),(28, 4.73832),(29, 6.03956),(30, 7.26995),(31, 8.34565),(32, 9.19335),(33, 9.75528),(34, 9.99315),(35, 9.89074),(36, 9.45503),(37, 8.71572),(38, 7.7232),(39, 6.54508),(40, 5.26168),(41, 3.96044),(42, 2.73005),(43, 1.65435),(44, 0.806647),(45, 0.244717),(46, 0.00685233),(47, 0.109262),(48, 0.544967)]
bac1=[(0, 1.26694),(1, 0.760635),(2, 0.293572),(3, 0.010409),(4, 0.201233),(5, 1.12894),(6, 2.7256),(7, 4.49296),(8, 5.79929),(9, 6.27491),(10, 5.94887),(11, 5.11694),(12, 4.12089),(13, 3.19399),(14, 2.42589),(15, 1.8035),(16, 1.26694),(17, 0.760635),(18, 0.293572),(19, 0.010409),(20, 0.201233),(21, 1.12894),(22, 2.7256),(23, 4.49296),(24, 5.79929),(25, 6.27491),(26, 5.94887),(27, 5.11694),(28, 4.12089),(29, 3.19399),(30, 2.42589),(31, 1.8035),(32, 1.26694),(33, 0.760635),(34, 0.293572),(35, 0.010409),(36, 0.201233),(37, 1.12894),(38, 2.7256),(39, 4.49296),(40, 5.79929),(41, 6.27491),(42, 5.94887),(43, 5.11694),(44, 4.12089),(45, 3.19399),(46, 2.42589),(47, 1.8035),(48, 1.3137)]
xC1, yC1 = zip(*csfb1)
xB1, yB1 = zip(*bac1)
axs[0,2].plot(xC05,yC05,color='green')
axs[0,2].plot(xB1,yB1,color='red',label='Bacteria')
axs[0,2].fill_between(xB1, yB1, alpha=0.2,color='red')
axs[0,2].set_xlim(0, 48)
axs[0,2].set_xticks([0,12,24,36,48])
axs[0,2].set_ylim(0, 12)
axs[0,2].set_yticks([0,2,4,6,8,10,12])
axs[0,2].yaxis.set_minor_locator(tck.AutoMinorLocator())
axs[0,2].xaxis.set_minor_locator(tck.AutoMinorLocator())
axs[0, 2].set_title(r'$\nu=1$')

#---amp and csfb for nu=0
amp0=[(0, 2.76537),(1, 3.41421),(2, 3.84776),(3, 4.),(4, 3.84776),(5, 3.41421),(6, 2.76537),(7, 2.),(8, 1.23463),(9, 0.585786),(10, 0.152241),(11, 0.),(12, 0.152241),(13, 0.585786),(14, 1.23463),(15, 2.),(16, 2.76537),(17, 3.41421),(18, 3.84776),(19, 4.),(20, 3.84776),(21, 3.41421),(22, 2.76537),(23, 2.),(24, 1.23463),(25, 0.585786),(26, 0.152241),(27, 0.),(28, 0.152241),(29, 0.585786),(30, 1.23463),(31, 2.),(32, 2.76537),(33, 3.41421),(34, 3.84776),(35, 4.),(36, 3.84776),(37, 3.41421),(38, 2.76537),(39, 2.),(40, 1.23463),(41, 0.585786),(42, 0.152241),(43, 0.),(44, 0.152241),(45, 0.585786),(46, 1.23463),(47, 2.),(48, 2.78311)]
xA0, yA0 = zip(*amp0)
axs[1,0].plot(xC0,yC0,color='green')
axs[1,0].plot(xA0, yA0, color='blue',label='AMP')
axs[1,0].fill_between(xA0, yA0, alpha=0.2,color='blue')
axs[1,0].set_xlim(0, 48)
axs[1,0].set_xticks([0,12,24,36,48])
axs[1,0].set_ylim(0, 12)
axs[1,0].set_yticks([0,2,4,6,8,10,12])
axs[1,0].yaxis.set_minor_locator(tck.AutoMinorLocator())
axs[1,0].xaxis.set_minor_locator(tck.AutoMinorLocator())
axs[1,0].set_xlabel('Time [hr]')
axs[1,0].set_ylabel('Local Concentrations')


#---amp and csfb for nu=0.5
amp05=[(0, 2.34842),(1, 2.52211),(2, 2.54001),(3, 2.40039),(4, 2.12859),(5, 1.77081),(6, 1.38447),(7, 1.02807),(8, 0.752303),(9, 0.594145),(10, 0.573974),(11, 0.694853),(12, 0.942406),(13, 1.28467),(14, 1.67328),(15, 2.04843),(16, 2.34842),(17, 2.52211),(18, 2.54001),(19, 2.40039),(20, 2.12859),(21, 1.77081),(22, 1.38447),(23, 1.02807),(24, 0.752303),(25, 0.594145),(26, 0.573974),(27, 0.694853),(28, 0.942406),(29, 1.28467),(30, 1.67328),(31, 2.04843),(32, 2.34842),(33, 2.52211),(34, 2.54001),(35, 2.40039),(36, 2.12859),(37, 1.77081),(38, 1.38447),(39, 1.02807),(40, 0.752303),(41, 0.594145),(42, 0.573974),(43, 0.694853),(44, 0.942406),(45, 1.28467),(46, 1.67328),(47, 2.04843),(48, 2.35029)]
xA05, yA05 = zip(*amp05)
axs[1,1].plot(xC05,yC05,color='green')
axs[1,1].plot(xA05, yA05, color='blue')
axs[1,1].fill_between(xA05, yA05, alpha=0.2,color='blue')
axs[1,1].set_xlim(0, 48)
axs[1,1].set_xticks([0,12,24,36,48])
axs[1,1].set_ylim(0, 12)
axs[1,1].set_yticks([0,2,4,6,8,10,12])
axs[1,1].yaxis.set_minor_locator(tck.AutoMinorLocator())
axs[1,1].xaxis.set_minor_locator(tck.AutoMinorLocator())
axs[1,1].set_xlabel('Time [hr]')


#---amp and csfb for nu=1
amp1=[(0, 2.00973),(1, 1.6733),(2, 1.24086),(3, 0.788034),(4, 0.392988),(5, 0.119281),(6, 0.00328038),(7, 0.0506858),(8, 0.243076),(9, 0.548884),(10, 0.929907),(11, 1.34069),(12, 1.72716),(13, 2.03072),(14, 2.19805),(15, 2.19345),(16, 2.00973),(17, 1.6733),(18, 1.24086),(19, 0.788034),(20, 0.392988),(21, 0.119281),(22, 0.00328038),(23, 0.0506858),(24, 0.243076),(25, 0.548884),(26, 0.929907),(27, 1.34069),(28, 1.72716),(29, 2.03072),(30, 2.19805),(31, 2.19345),(32, 2.00973),(33, 1.6733),(34, 1.24086),(35, 0.788034),(36, 0.392988),(37, 0.119281),(38, 0.00328038),(39, 0.0506858),(40, 0.243076),(41, 0.548884),(42, 0.929907),(43, 1.34069),(44, 1.72716),(45, 2.03072),(46, 2.19805),(47, 2.19345),(48, 1.9812)]
xA1, yA1 = zip(*amp1)
axs[1,2].plot(xC1,yC1,color='green',label= '$C_{SFB}$')
axs[1,2].plot(xA1, yA1, color='blue')
axs[1,2].fill_between(xA1, yA1, alpha=0.2,color='blue')
axs[1,2].set_xlim(0, 48)
axs[1,2].set_xticks([0,12,24,36,48])
axs[1,2].set_ylim(0, 12)
axs[1,2].set_yticks([0,2,4,6,8,10,12])
axs[1,2].yaxis.set_minor_locator(tck.AutoMinorLocator())
axs[1,2].xaxis.set_minor_locator(tck.AutoMinorLocator())
axs[1,2].set_xlabel('Time [hr]')

axs[0,2].legend(bbox_to_anchor=(-.4, -0.24),ncol=1)
axs[1,0].legend(bbox_to_anchor=(.25, 1.05),ncol=1)
axs[1,2].legend(bbox_to_anchor=(.9, 1.4),ncol=1)



# set the spacing between subplots
plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.6)
plt.show()

# %%
fig.savefig('Fig3.png', format='png', dpi=1000)
