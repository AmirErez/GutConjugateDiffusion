# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as tck

fig, axs = plt.subplots(2, 3)

#-----for nu=0, csfb and bac
csfb0=[(0, 10.),(1, 9.82963),(2, 9.33013),(3, 8.53553),(4, 7.5),(5, 6.2941),(6, 5.),(7, 3.7059),(8, 2.5),(9, 1.46447),(10, 0.669873),(11, 0.170371),(12, 0.),(13, 0.170371),(14, 0.669873),(15, 1.46447),(16, 2.5),(17, 3.7059),(18, 5.),(19, 6.2941),(20, 7.5),(21, 8.53553),(22, 9.33013),(23, 9.82963),(24, 10.),(25, 9.82963),(26, 9.33013),(27, 8.53553),(28, 7.5),(29, 6.2941),(30, 5.),(31, 3.7059),(32, 2.5),(33, 1.46447),(34, 0.669873),(35, 0.170371),(36, 0.),(37, 0.170371),(38, 0.669873),(39, 1.46447),(40, 2.5),(41, 3.7059),(42, 5.),(43, 6.2941),(44, 7.5),(45, 8.53553),(46, 9.33013),(47, 9.82963),(48, 10.)]
bac0=[(0, 0.0591348),(1, 0.0592146),(2, 0.0681004),(3, 0.0895573),(4, 0.132311),(5, 0.213223),(6, 0.360464),(7, 0.610464),(8, 0.984579),(9, 1.43403),(10, 1.78528),(11, 1.79079),(12, 1.34542),(13, 0.669873),(14, 0.156522),(15, 0.),(16, 0.0820743),(17, 0.192123),(18, 0.229085),(19, 0.203488),(20, 0.156504),(21, 0.114266),(22, 0.0847211),(23, 0.067168),(24, 0.0591348),(25, 0.0592146),(26, 0.0681004),(27, 0.0895573),(28, 0.132311),(29, 0.213223),(30, 0.360464),(31, 0.610464),(32, 0.984579),(33, 1.43403),(34, 1.78528),(35, 1.79079),(36, 1.34542),(37, 0.669873),(38, 0.156522),(39, 0.),(40, 0.0820743),(41, 0.192123),(42, 0.229085),(43, 0.203488),(44, 0.156504),(45, 0.114266),(46, 0.0847211),(47, 0.067168),(48, 0.0591348)]
xC0, yC0 = zip(*csfb0)
xB0, yB0 = zip(*bac0)
axs[0,0].plot(xC0,yC0,color='green')
axs[0,0].plot(xB0,yB0,color='red')
axs[0,0].fill_between(xB0, yB0, alpha=0.2,color='red')
axs[0,0].set_xlim(0, 48)
axs[0,0].set_xticks([0,12,24,36,48])
axs[0,0].set_ylim(0, 12)
axs[0,0].set_yticks([0,2,4,6,8,10,12])
axs[0,0].yaxis.set_minor_locator(tck.AutoMinorLocator())
axs[0,0].xaxis.set_minor_locator(tck.AutoMinorLocator())
axs[0, 0].set_title(r'$\nu=0$')
axs[0,0].set_ylabel('Local Concentrations')


#-----for nu=0.5, csfb and bac
csfb05=[(0, 10.),(1, 9.82963),(2, 9.33013),(3, 8.53553),(4, 7.5),(5, 6.2941),(6, 5.),(7, 3.7059),(8, 2.5),(9, 1.46447),(10, 0.669873),(11, 0.170371),(12, 0.),(13, 0.170371),(14, 0.669873),(15, 1.46447),(16, 2.5),(17, 3.7059),(18, 5.),(19, 6.2941),(20, 7.5),(21, 8.53553),(22, 9.33013),(23, 9.82963),(24, 10.),(25, 9.82963),(26, 9.33013),(27, 8.53553),(28, 7.5),(29, 6.2941),(30, 5.),(31, 3.7059),(32, 2.5),(33, 1.46447),(34, 0.669873),(35, 0.170371),(36, 0.),(37, 0.170371),(38, 0.669873),(39, 1.46447),(40, 2.5),(41, 3.7059),(42, 5.),(43, 6.2941),(44, 7.5),(45, 8.53553),(46, 9.33013),(47, 9.82963),(48, 10.)]
bac05=[(0, 0.0515143),(1, 0.0353169),(2, 0.0279763),(3, 0.0263024),(4, 0.0296169),(5, 0.0395696),(6, 0.0610448),(7, 0.104146),(8, 0.18569),(9, 0.323597),(10, 0.511375),(11, 0.674764),(12, 0.675475),(13, 0.446222),(14, 0.136702),(15, 0.),(16, 0.118303),(17, 0.343364),(18, 0.482937),(19, 0.469315),(20, 0.358878),(21, 0.234605),(22, 0.14088),(23, 0.0832102),(24, 0.0515143),(25, 0.0353169),(26, 0.0279763),(27, 0.0263024),(28, 0.0296169),(29, 0.0395696),(30, 0.0610448),(31, 0.104146),(32, 0.18569),(33, 0.323597),(34, 0.511375),(35, 0.674764),(36, 0.675475),(37, 0.446222),(38, 0.136702),(39, 0.),(40, 0.118303),(41, 0.343364),(42, 0.482937),(43, 0.469315),(44, 0.358878),(45, 0.234605),(46, 0.14088),(47, 0.0832102),(48, 0.0515143)]
xC05, yC05 = zip(*csfb05)
xB05, yB05 = zip(*bac05)
axs[0,1].plot(xC05,yC05,color='green')
axs[0,1].plot(xB05,yB05,color='red')
axs[0,1].fill_between(xB05, yB05, alpha=0.2,color='red')
axs[0,1].set_xlim(0, 48)
axs[0,1].set_xticks([0,12,24,36,48])
axs[0,1].set_ylim(0, 12)
axs[0,1].set_yticks([0,2,4,6,8,10,12])
axs[0,1].yaxis.set_minor_locator(tck.AutoMinorLocator())
axs[0,1].xaxis.set_minor_locator(tck.AutoMinorLocator())
axs[0,1].set_title(r'$\nu=0.5$')

#-----for nu=1 csfb and bac
csfb1=[(0, 10.),(1, 9.82963),(2, 9.33013),(3, 8.53553),(4, 7.5),(5, 6.2941),(6, 5.),(7, 3.7059),(8, 2.5),(9, 1.46447),(10, 0.669873),(11, 0.170371),(12, 0.),(13, 0.170371),(14, 0.669873),(15, 1.46447),(16, 2.5),(17, 3.7059),(18, 5.),(19, 6.2941),(20, 7.5),(21, 8.53553),(22, 9.33013),(23, 9.82963),(24, 10.),(25, 9.82963),(26, 9.33013),(27, 8.53553),(28, 7.5),(29, 6.2941),(30, 5.),(31, 3.7059),(32, 2.5),(33, 1.46447),(34, 0.669873),(35, 0.170371),(36, 0.),(37, 0.170371),(38, 0.669873),(39, 1.46447),(40, 2.5),(41, 3.7059),(42, 5.),(43, 6.2941),(44, 7.5),(45, 8.53553),(46, 9.33013),(47, 9.82963),(48, 10.)]
bac1=[(0, 0.0474569),(1, 0.0207437),(2, 0.0105076),(3, 0.00658293),(4, 0.00531427),(5, 0.00560952),(6, 0.00764599),(7, 0.0129497),(8, 0.025625),(9, 0.0546556),(10, 0.114193),(11, 0.209709),(12, 0.298713),(13, 0.278739),(14, 0.117009),(15, 0.),(16, 0.170371),(17, 0.615159),(18, 1.04252),(19, 1.15536),(20, 0.921779),(21, 0.557563),(22, 0.271444),(23, 0.115549),(24, 0.0474569),(25, 0.0207437),(26, 0.0105076),(27, 0.00658293),(28, 0.00531427),(29, 0.00560952),(30, 0.00764599),(31, 0.0129497),(32, 0.025625),(33, 0.0546556),(34, 0.114193),(35, 0.209709),(36, 0.298713),(37, 0.278739),(38, 0.117009),(39, 0.),(40, 0.170371),(41, 0.615159),(42, 1.04252),(43, 1.15536),(44, 0.921779),(45, 0.557563),(46, 0.271444),(47, 0.115549),(48, 0.0474569)]
xC1, yC1 = zip(*csfb1)
xB1, yB1 = zip(*bac1)
axs[0,2].plot(xC05,yC05,color='green')
axs[0,2].plot(xB1,yB1,color='red')
axs[0,2].fill_between(xB1, yB1, alpha=0.2,color='red')
axs[0,2].set_xlim(0, 48)
axs[0,2].set_xticks([0,12,24,36,48])
axs[0,2].set_ylim(0, 12)
axs[0,2].set_yticks([0,2,4,6,8,10,12])
axs[0,2].yaxis.set_minor_locator(tck.AutoMinorLocator())
axs[0,2].xaxis.set_minor_locator(tck.AutoMinorLocator())
axs[0, 2].set_title(r'$\nu=1$')

#---amp and csfb for nu=0
amp0=[(0, 9.82963),(1, 10.),(2, 9.82963),(3, 9.33013),(4, 8.53553),(5, 7.5),(6, 6.2941),(7, 5.),(8, 3.7059),(9, 2.5),(10, 1.46447),(11, 0.669873),(12, 0.170371),(13, 0.),(14, 0.170371),(15, 0.669873),(16, 1.46447),(17, 2.5),(18, 3.7059),(19, 5.),(20, 6.2941),(21, 7.5),(22, 8.53553),(23, 9.33013),(24, 9.82963),(25, 10.),(26, 9.82963),(27, 9.33013),(28, 8.53553),(29, 7.5),(30, 6.2941),(31, 5.),(32, 3.7059),(33, 2.5),(34, 1.46447),(35, 0.669873),(36, 0.170371),(37, 0.),(38, 0.170371),(39, 0.669873),(40, 1.46447),(41, 2.5),(42, 3.7059),(43, 5.),(44, 6.2941),(45, 7.5),(46, 8.53553),(47, 9.33013),(48, 9.82963)]
xA0, yA0 = zip(*amp0)
axs[1,0].plot(xC0,yC0,color='green')
axs[1,0].plot(xA0, yA0, color='blue')
axs[1,0].fill_between(xA0, yA0, alpha=0.2,color='blue')
axs[1,0].set_xlim(0, 48)
axs[1,0].set_xticks([0,12,24,36,48])
axs[1,0].set_ylim(0, 16)
axs[1,0].set_yticks([0,2,4,6,8,10,12,14,16])
axs[1,0].yaxis.set_minor_locator(tck.AutoMinorLocator())
axs[1,0].xaxis.set_minor_locator(tck.AutoMinorLocator())
axs[1,0].set_xlabel('Time [hr]')
axs[1,0].set_ylabel('Local Concentrations')


#---amp and csfb for nu=0.5
amp05=[(0, 10.0977),(1, 11.0024),(2, 11.5539),(3, 11.7063),(4, 11.4438),(5, 10.7821),(6, 9.76782),(7, 8.47472),(8, 6.9991),(9, 5.45279),(10, 3.9548),(11, 2.62103),(12, 1.55142),(13, 0.815519),(14, 0.442243),(15, 0.423467),(16, 0.732233),(17, 1.34032),(18, 2.22162),(19, 3.34361),(20, 4.6564),(21, 6.08678),(22, 7.54075),(23, 8.91274),(24, 10.0977),(25, 11.0024),(26, 11.5539),(27, 11.7063),(28, 11.4438),(29, 10.7821),(30, 9.76782),(31, 8.47472),(32, 6.9991),(33, 5.45279),(34, 3.9548),(35, 2.62103),(36, 1.55142),(37, 0.815519),(38, 0.442243),(39, 0.423467),(40, 0.732233),(41, 1.34032),(42, 2.22162),(43, 3.34361),(44, 4.6564),(45, 6.08678),(46, 7.54075),(47, 8.91274),(48, 10.0977)]
xA05, yA05 = zip(*amp05)
axs[1,1].plot(xC05,yC05,color='green')
axs[1,1].plot(xA05, yA05, color='blue')
axs[1,1].fill_between(xA05, yA05, alpha=0.2,color='blue')
axs[1,1].set_xlim(0, 48)
axs[1,1].set_xticks([0,12,24,36,48])
axs[1,1].set_ylim(0, 16)
axs[1,1].set_yticks([0,2,4,6,8,10,12,14,16])
axs[1,1].yaxis.set_minor_locator(tck.AutoMinorLocator())
axs[1,1].xaxis.set_minor_locator(tck.AutoMinorLocator())
axs[1,1].set_xlabel('Time [hr]')


#---amp and csfb for nu=1
amp1=[(0, 10.257),(1, 12.0308),(2, 13.4401),(3, 14.3692),(4, 14.7457),(5, 14.5427),(6, 13.7792),(7, 12.5181),(8, 10.8613),(9, 8.9417),(10, 6.91369),(11, 4.94047),(12, 3.17857),(13, 1.75728),(14, 0.75428),(15, 0.180896),(16, 0.),(17, 0.171223),(18, 0.682344),(19, 1.54751),(20, 2.78376),(21, 4.37708),(22, 6.25279),(23, 8.27172),(24, 10.257),(25, 12.0308),(26, 13.4401),(27, 14.3692),(28, 14.7457),(29, 14.5427),(30, 13.7792),(31, 12.5181),(32, 10.8613),(33, 8.9417),(34, 6.91369),(35, 4.94047),(36, 3.17857),(37, 1.75728),(38, 0.75428),(39, 0.180896),(40, 0.),(41, 0.171223),(42, 0.682344),(43, 1.54751),(44, 2.78376),(45, 4.37708),(46, 6.25279),(47, 8.27172),(48, 10.257)]
xA1, yA1 = zip(*amp1)
axs[1,2].plot(xC1,yC1,color='green')
axs[1,2].plot(xA1, yA1, color='blue')
axs[1,2].fill_between(xA1, yA1, alpha=0.2,color='blue')
axs[1,2].set_xlim(0, 48)
axs[1,2].set_xticks([0,12,24,36,48])
axs[1,2].set_ylim(0, 16)
axs[1,2].set_yticks([0,2,4,6,8,10,12,14,16])
axs[1,2].yaxis.set_minor_locator(tck.AutoMinorLocator())
axs[1,2].xaxis.set_minor_locator(tck.AutoMinorLocator())
axs[1,2].set_xlabel('Time [hr]')


# set the spacing between subplots
plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.4, 
                    hspace=0.4)
plt.show()
# Out:
# findfont: Font family ['cmsy10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmr10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmtt10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmmi10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmb10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmss10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['cmex10'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['DejaVu Sans Display'] not found. Falling back to DejaVu Sans.
