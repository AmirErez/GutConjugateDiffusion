# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as tck

fig, axs = plt.subplots(1, 2)

plt.rcParams['text.usetex'] = True  #enable using LaTeX in matplotlib
plt.rcParams.update({'font.size': 18})

#---NO Amp Removal and SAME bulk values BM1=BM2=5.5
bacNamp55=[(0., 0.00244435),(0.025, 0.00372236),(0.05, 0.0056085),(0.075, 0.00835753),(0.1, 0.0123137),(0.125, 0.0179451),(0.15, 0.0258748),(0.175, 0.0369018),(0.2, 0.052043),(0.225, 0.0726032),(0.25, 0.100213),(0.275, 0.136825),(0.3, 0.184763),(0.325, 0.246817),(0.35, 0.326222),(0.375, 0.426541),(0.4, 0.551663),(0.425, 0.705872),(0.45, 0.893649),(0.475, 1.11931),(0.5, 1.38693),(0.525, 1.7003),(0.55, 2.06252),(0.575, 2.47542),(0.6, 2.93944),(0.625, 3.45367),(0.65, 4.01527),(0.675, 4.6191),(0.7, 5.25789),(0.725, 5.92236),(0.75, 6.60109),(0.775, 7.28076),(0.8, 7.94675),(0.825, 8.58345),(0.85, 9.17474),(0.875, 9.70503),(0.9, 10.1599),(0.925, 10.5261),(0.95, 10.7928),(0.975, 10.9523),(1., 11.)]
x1, y1 = zip(*bacNamp55)

#---WITH Amp Removal and SAME bulk values BM1=BM2=5.5
bacWamp55=[(0., 0.0142848),(0.05, 0.0303814),(0.1, 0.0614612),(0.15, 0.11828),(0.2, 0.216585),(0.25, 0.377469),(0.3, 0.62643),(0.35, 0.990607),(0.4, 1.49414),(0.45, 2.15237),(0.5, 2.96632),(0.55, 3.91926),(0.6, 4.97655),(0.65, 6.08913),(0.7, 7.19952),(0.75, 8.24871),(0.8, 9.18218),(0.85, 9.95403),(0.9, 10.5289),(0.95, 10.8823),(1., 11.)]
x2, y2 = zip(*bacWamp55)


#---------------------------------------

#---NO Amp Removal and DIFFERENT bulk values BM1=10;BM2=1
bacNamp101=[(0., 0.00244435),(0.05, 0.0056085),(0.1, 0.0123137),(0.15, 0.0258748),(0.2, 0.052043),(0.25, 0.100213),(0.3, 0.184763),(0.35, 0.326222),(0.4, 0.551663),(0.45, 0.893649),(0.5, 1.38693),(0.55, 2.06252),(0.6, 2.93944),(0.65, 4.01527),(0.7, 5.25789),(0.75, 6.60109),(0.8, 7.94675),(0.85, 9.17474),(0.9, 10.1599),(0.95, 10.7928),(1., 11.)]
x3,y3 = zip(*bacNamp101)

#---WITH Amp Removal  and DIFFERENT bulk values BM1=10;BM2=1
bacWamp101=[(0., 0.0142848),(0.05, 0.0303814),(0.1, 0.0614612),(0.15, 0.11828),(0.2, 0.216585),(0.25, 0.377469),(0.3, 0.62643),(0.35, 0.990607),(0.4, 1.49414),(0.45, 2.15237),(0.5, 2.96632),(0.55, 3.91926),(0.6, 4.97655),(0.65, 6.08913),(0.7, 7.19952),(0.75, 8.24871),(0.8, 9.18218),(0.85, 9.95403),(0.9, 10.5289),(0.95, 10.8823),(1., 11.)]
x4, y4 = zip(*bacWamp101)





#----- equal bulk values
axs[0].plot(x1,y1,color='blue',label='without AMP removal') #without AMP removal
axs[0].plot(x2,y2,color='blue',marker=".",linestyle= 'None',label='with AMP removal') #with amp removal

#axs[0].fill_between(xB0, yB0, alpha=0.2,color='red')
axs[0].set_xlim(0, 1)
#axs[0].set_xticks([0,12,24,36,48])
axs[0].set_ylim(0, 12)
axs[0].set_yticks([0,2,4,6,8,10,12])
axs[0].yaxis.set_minor_locator(tck.AutoMinorLocator())
axs[0].xaxis.set_minor_locator(tck.AutoMinorLocator())
axs[0].set_title(r'$b_{M1}=5.5; b_{M2}=5.5$',fontsize=18)
axs[0].set_ylabel('Local Concentrations')
axs[0].set_xlabel('Distance z')
axs[0].tick_params(axis='both', which='major')
axs[0].tick_params(axis='both', which='minor')



#---With Different bulk concentrations
axs[1].plot(x3,y3,color='red',label='without AMP removal') # without AMP removal
axs[1].plot(x4,y4,color='red',marker=".",linestyle= 'None',label='with AMP removal')#with amp removal


#axs[0].fill_between(xB0, yB0, alpha=0.2,color='red')
axs[1].set_xlim(0, 1)
#axs[0].set_xticks([0,12,24,36,48])
axs[1].set_ylim(0, 12)
axs[1].set_yticks([0,2,4,6,8,10,12])
axs[1].yaxis.set_minor_locator(tck.AutoMinorLocator())
axs[1].xaxis.set_minor_locator(tck.AutoMinorLocator())
axs[1].set_title(r'$b_{M1}=10; b_{M2}=1$',fontsize=18)
#axs[1].set_ylabel('Local Concentrations')
axs[1].set_xlabel('Distance z')
axs[1].tick_params(axis='both', which='major')
axs[1].tick_params(axis='both', which='minor')


axs[0].legend(bbox_to_anchor=(3.5, .9),ncol=1,prop={'size': 14})
#axs[0].text(.60, .06, r'Hello', transform=axs[0].transAxes)

axs[1].legend(bbox_to_anchor=(1.055, .7),ncol=1,prop={'size': 14})

axs[0].xaxis.set_ticks_position('both')
axs[0].yaxis.set_ticks_position('both')

axs[1].xaxis.set_ticks_position('both')
axs[1].yaxis.set_ticks_position('both')



# set the spacing between subplots
plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.27, 
                    hspace=1.2)
plt.savefig('figApp-3.png', bbox_inches="tight",transparent=False)
plt.show()
