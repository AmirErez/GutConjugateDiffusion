# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as tck


plt.rcParams['text.usetex'] = True  #enable using LaTeX in matplotlib
plt.rcParams.update({'font.size': 18})

fig, axs = plt.subplots(1, 2)

#---NO Amp Removal and SAME bulk values for both bacteria species-----Lb=2/3 --- alpha - beta=0.4
#---Amp with NO Amp removal - bm1=bm2
AmpNoRemSb23=[(0., 2.57509),(0.05, 2.44634),(0.1, 2.31758),(0.15, 2.18883),(0.2, 2.06008),(0.25, 1.93132),(0.3, 1.80257),(0.35, 1.67381),(0.4, 1.54506),(0.45, 1.4163),(0.5, 1.28755),(0.55, 1.15879),(0.6, 1.03004),(0.65, 0.901283),(0.7, 0.772528),(0.75, 0.643774),(0.8, 0.515019),(0.85, 0.386264),(0.9, 0.257509),(0.95, 0.128755),(1., 0.)]
xAns13, yAns13 = zip(*AmpNoRemSb23)

#Bac 1 NO Amp removal - bm1=bm2  
Bac1NoRemSb23=[(0., 1.51882),(0.05, 1.72262),(0.1, 1.9411),(0.15, 2.17312),(0.2, 2.41713),(0.25, 2.67115),(0.3, 2.93277),(0.35, 3.1992),(0.4, 3.46729),(0.45, 3.73358),(0.5, 3.99438),(0.55, 4.24584),(0.6, 4.48403),(0.65, 4.70506),(0.7, 4.9052),(0.75, 5.08094),(0.8, 5.22911),(0.85, 5.347),(0.9, 5.43241),(0.95, 5.48373),(1., 5.5)]
xB1ns13,yB1ns13 = zip(*Bac1NoRemSb23)

#---Bac 2 NO amp removal - bm1=bm2
Bac2NoRemSb23=[(0., 1.51882),(0.05, 1.72262),(0.1, 1.9411),(0.15, 2.17312),(0.2, 2.41713),(0.25, 2.67115),(0.3, 2.93277),(0.35, 3.1992),(0.4, 3.46729),(0.45, 3.73358),(0.5, 3.99438),(0.55, 4.24584),(0.6, 4.48403),(0.65, 4.70506),(0.7, 4.9052),(0.75, 5.08094),(0.8, 5.22911),(0.85, 5.347),(0.9, 5.43241),(0.95, 5.48373),(1., 5.5)]
xB2ns13,yB2ns13 = zip(*Bac2NoRemSb23)

#---LPS No Amp removal - bm1=bm2
LpsNoRemSb23=[(0., 6.43774),(0.05, 6.81768),(0.1, 7.18892),(0.15, 7.55036),(0.2, 7.90083),(0.25, 8.23911),(0.3, 8.56393),(0.35, 8.87398),(0.4, 9.16793),(0.45, 9.44443),(0.5, 9.70216),(0.55, 9.93982),(0.6, 10.1562),(0.65, 10.35),(0.7, 10.5202),(0.75, 10.6659),(0.8, 10.7861),(0.85, 10.8801),(0.9, 10.9473),(0.95, 10.9874),(1., 11.)]
xLns13,yLns13 = zip(*LpsNoRemSb23)

#---------------------------------------

#---WITH Amp Removal and SAME bulk values for both bacteria species-----Lb=2/3 - beta=0.4
#Amp WITH Amp removal - bm1=bm2
xB1wd23,yB1wd23 = zip(*Bac1WithRemDb23)

#Bac 2 WITH Amp removal - bm1=19 bm2=1
Bac2WithRemDb23=[(0., 0.485078),(0.05, 0.54158),(0.1, 0.596085),(0.15, 0.64774),(0.2, 0.695917),(0.25, 0.74021),(0.3, 0.780408),(0.35, 0.816468),(0.4, 0.848471),(0.45, 0.876592),(0.5, 0.901065),(0.55, 0.922158),(0.6, 0.940149),(0.65, 0.955311),(0.7, 0.967899),(0.75, 0.978145),(0.8, 0.986248),(0.85, 0.992374),(0.9, 0.996652),(0.95, 0.999176),(1., 1.)]
xB2wd23,yB2wd23 = zip(*Bac2WithRemDb23)

#LPS WITH Amp removal - bm1=19 bm2=1
LpsWithRemDb23=[(0., 5.89305),(0.05, 6.35168),(0.1, 6.7954),(0.15, 7.2227),(0.2, 7.63217),(0.25, 8.02248),(0.3, 8.39243),(0.35, 8.7409),(0.4, 9.06691),(0.45, 9.36958),(0.5, 9.64814),(0.55, 9.90191),(0.6, 10.1303),(0.65, 10.3329),(0.7, 10.5092),(0.75, 10.6588),(0.8, 10.7816),(0.85, 10.8772),(0.9, 10.9456),(0.95, 10.9865),(1., 11.)]
xLwd23,yLwd23 = zip(*LpsWithRemDb23)

#---------------------------------------
#----+----+----+----+----+----+----+----
#---------------------------------------


#---NO Amp Removal and SAME bulk values for both bacteria species-----Lb=1/4 - beta=2
#---Amp with NO Amp removal - bm1=bm2
AmpNoRemSb14=[(0., 16.5159),(0.05, 15.6901),(0.1, 14.8643),(0.15, 14.0385),(0.2, 13.2127),(0.25, 12.3869),(0.3, 11.5611),(0.35, 10.7353),(0.4, 9.90953),(0.45, 9.08373),(0.5, 8.25794),(0.55, 7.43214),(0.6, 6.60635),(0.65, 5.78056),(0.7, 4.95476),(0.75, 4.12897),(0.8, 3.30318),(0.85, 2.47738),(0.9, 1.65159),(0.95, 0.825794),(1., 0.)]
xAns14, yAns14 = zip(*AmpNoRemSb14)

#Bac 1 NO Amp removal - bm1=bm2  
Bac1NoRemSb14=[(0., 0.00122217),(0.05, 0.00280425),(0.1, 0.00615685),(0.15, 0.0129374),(0.2, 0.0260215),(0.25, 0.0501064),(0.3, 0.0923817),(0.35, 0.163111),(0.4, 0.275832),(0.45, 0.446825),(0.5, 0.693464),(0.55, 1.03126),(0.6, 1.46972),(0.65, 2.00764),(0.7, 2.62895),(0.75, 3.30055),(0.8, 3.97338),(0.85, 4.58737),(0.9, 5.07994),(0.95, 5.39641),(1., 5.5)]
xB1ns14,yB1ns14 = zip(*Bac1NoRemSb14)

#---Bac 2 NO amp removal - bm1=bm2
#LPS WITH Amp removal - bm1=bm2
LpsWithRemSb14=[(0., 7.74138),(0.05, 7.95544),(0.1, 8.16942),(0.15, 8.38323),(0.2, 8.59674),(0.25, 8.80969),(0.3, 9.02166),(0.35, 9.23203),(0.4, 9.43988),(0.45, 9.64392),(0.5, 9.84252),(0.55, 10.0336),(0.6, 10.2149),(0.65, 10.3836),(0.7, 10.537),(0.75, 10.6724),(0.8, 10.7872),(0.85, 10.879),(0.9, 10.9459),(0.95, 10.9865),(1., 11.)]
xLws14,yLws14 = zip(*LpsWithRemSb14)


#--#--#--#--#--#--#--#--#--#--#--#--#--#--#

#---NO Amp Removal and DIFFERENT bulk values for both bacteria species-----Lb=1/4 - beta=2
#Amp NO Amp removal - bm1=19 bm2=1
AmpNoRemDb14=[(0., 16.5428),(0.05, 15.7156),(0.1, 14.8885),(0.15, 14.0614),(0.2, 13.2342),(0.25, 12.4071),(0.3, 11.58),(0.35, 10.7528),(0.4, 9.92567),(0.45, 9.09853),(0.5, 8.27139),(0.55, 7.44425),(0.6, 6.61712),(0.65, 5.78998),(0.7, 4.96284),(0.75, 4.1357),(0.8, 3.30856),(0.85, 2.48142),(0.9, 1.65428),(0.95, 0.827139),(1., 0.)]
xAnd14, yAnd14 = zip(*AmpNoRemDb14)

#Bac 1 NO Amp removal - bm1=19 bm2=1
Bac1NoRemDb14=[(0., 0.00246279),(0.05, 0.00555063),(0.1, 0.0119953),(0.15, 0.0248568),(0.2, 0.0493926),(0.25, 0.0941191),(0.3, 0.171992),(0.35, 0.301415),(0.4, 0.506602),(0.45, 0.816634),(0.5, 1.26259),(0.55, 1.87235),(0.6, 2.66326),(0.65, 3.63381),(0.7, 4.75603),(0.75, 5.9714),(0.8, 7.19237),(0.85, 8.31089),(0.9, 9.21335),(0.95, 9.79934),(1., 10.)]
xB1nd14,yB1nd14 = zip(*Bac1NoRemDb14)

#Bac 2 NO Amp removal - bm1=19 bm2=1
Bac2NoRemDb14=[(0., 0.000246279),(0.05, 0.000555063),(0.1, 0.00119953),(0.15, 0.00248568),(0.2, 0.00493926),(0.25, 0.00941191),(0.3, 0.0171992),(0.35, 0.0301415),(0.4, 0.0506602),(0.45, 0.0816634),(0.5, 0.126259),(0.55, 0.187235),(0.6, 0.266326),(0.65, 0.363381),(0.7, 0.475603),(0.75, 0.59714),(0.8, 0.719237),(0.85, 0.831089),(0.9, 0.921335),(0.95, 0.979934),(1., 1.)]
xB2nd14,yB2nd14 = zip(*Bac2NoRemDb14)

#---LPS No Amp removal - bm1=19 bm2=1
LpsNoRemDb14=[(0., 8.27139),(0.05, 8.44123),(0.1, 8.61105),(0.15, 8.78083),(0.2, 8.95054),(0.25, 9.12011),(0.3, 9.28941),(0.35, 9.45822),(0.4, 9.62617),(0.45, 9.79269),(0.5, 9.95692),(0.55, 10.1176),(0.6, 10.2731),(0.65, 10.4211),(0.7, 10.5591),(0.75, 10.6839),(0.8, 10.7922),(0.85, 10.8806),(0.9, 10.9463),(0.95, 10.9866),(1., 11.)]
xLnd14,yLnd14 = zip(*LpsNoRemDb14)

#---------------------------------------

#---WITH Amp Removal and DIFFERENT bulk values for both bacteria species-----Lb=1/4 -- beta=2
#Amp WITH Amp removal - bm1=19 bm2=1
AmpWithRemDb14=[(0., 15.4828),(0.05, 14.4956),(0.1, 13.5096),(0.15, 12.5258),(0.2, 11.5458),(0.25, 10.5722),(0.3, 9.60877),(0.35, 8.66062),(0.4, 7.73415),(0.45, 6.83676),(0.5, 5.97629),(0.55, 5.16017),(0.6, 4.39453),(0.65, 3.68339),(0.7, 3.02808),(0.75, 2.42696),(0.8, 1.87556),(0.85, 1.36689),(0.9, 0.891911),(0.95, 0.440106),(1., 0.)]
xAwd14, yAwd14 = zip(*AmpWithRemDb14)

#Bac 1 WITH Amp removal - bm1=19 bm2=1
Bac1WithRemDb14=[(0., 0.0129862),(0.05, 0.0276194),(0.1, 0.0558738),(0.15, 0.107527),(0.2, 0.196895),(0.25, 0.343154),(0.3, 0.569482),(0.35, 0.900552),(0.4, 1.35831),(0.45, 1.9567),(0.5, 2.69665),(0.55, 3.56296),(0.6, 4.52414),(0.65, 5.53557),(0.7, 6.54502),(0.75, 7.49882),(0.8, 8.34744),(0.85, 9.04912),(0.9, 9.57171),(0.95, 9.89298),(1., 10.)]
xB1wd14,yB1wd14 = zip(*Bac1WithRemDb14)

#Bac 2 WITH Amp removal - bm1=19 bm2=1
Bac2WithRemDb14=[(0., 0.00129862),(0.05, 0.00276194),(0.1, 0.00558738),(0.15, 0.0107527),(0.2, 0.0196895),(0.25, 0.0343154),(0.3, 0.0569482),(0.35, 0.0900552),(0.4, 0.135831),(0.45, 0.19567),(0.5, 0.269665),(0.55, 0.356296),(0.6, 0.452414),(0.65, 0.553557),(0.7, 0.654502),(0.75, 0.749882),(0.8, 0.834744),(0.85, 0.904912),(0.9, 0.957171),(0.95, 0.989298),(1., 1.)]
xB2wd14,yB2wd14 = zip(*Bac2WithRemDb14)

#LPS WITH Amp removal - bm1=19 bm2=1
LpsWithRemDb14=[(0., 7.74138),(0.05, 7.95544),(0.1, 8.16942),(0.15, 8.38323),(0.2, 8.59674),(0.25, 8.80969),(0.3, 9.02166),(0.35, 9.23203),(0.4, 9.43988),(0.45, 9.64392),(0.5, 9.84252),(0.55, 10.0336),(0.6, 10.2149),(0.65, 10.3836),(0.7, 10.537),(0.75, 10.6724),(0.8, 10.7872),(0.85, 10.879),(0.9, 10.9459),(0.95, 10.9865),(1., 11.)]
xLwd14,yLwd14 = zip(*LpsWithRemDb14)




#-----for lb=1/3 but with equal bulk values
axs[0].plot(xAns13,yAns13,color='blue')
axs[0].plot(xB1ns13,yB1ns13,color='red')
#axs[0].plot(xB2ns13,yB2ns13,color='orange')
axs[0].plot(xLns13,yLns13,color='gray')
#----
axs[0].plot(xAws13,yAws13,color='blue',marker=".",linestyle= 'None',label='AMP')
axs[0].plot(xB1ws13,yB1ws13,color='red',marker=".",linestyle= 'None',label='Bacteria')
#axs[0].plot(xB2ws13,yB2ws13,color='orange',marker=".",linestyle= 'None')
axs[0].plot(xLws13,yLws13,color='gray',marker=".",linestyle= 'None',label='LPS')

#axs[0].fill_between(xB0, yB0, alpha=0.2,color='red')
axs[0].set_xlim(0, 1)
#axs[0].set_xticks([0,12,24,36,48])
axs[0].set_ylim(0, 12)
axs[0].set_yticks([0,2,4,6,8,10,12])
axs[0].yaxis.set_minor_locator(tck.AutoMinorLocator())
axs[0].xaxis.set_minor_locator(tck.AutoMinorLocator())
axs[0].set_title(r'$\beta=0.4$')
axs[0].set_ylabel('Local Concentrations')
axs[0].set_xlabel('Distance z')
axs[0].tick_params(axis='both', which='major')
axs[0].tick_params(axis='both', which='minor')



#-----for lb=1/4 but with equal bulk values
#----lines are without amp removal
axs[1].plot(xAns14,yAns14,color='blue',label='AMP')
axs[1].plot(xB1ns14,yB1ns14,color='red',label='Bacteria')
#axs[1].plot(xB2ns14,yB2ns14,color='orange')
axs[1].plot(xLns14,yLns14,color='gray',label='LPS')
#----
#-----symbols are with amp removal
axs[1].plot(xAws14,yAws14,color='blue',marker=".",linestyle= 'None')
axs[1].plot(xB1ws14,yB1ws14,color='red',marker=".",linestyle= 'None')
#axs[1].plot(xB2ws14,yB2ws14,color='orange',marker=".",linestyle= 'None')
axs[1].plot(xLws14,yLws14,color='gray',marker=".",linestyle= 'None')

#axs[0].fill_between(xB0, yB0, alpha=0.2,color='red')
axs[1].set_xlim(0, 1)
#axs[0].set_xticks([0,12,24,36,48])
axs[1].set_ylim(0, 20)
axs[1].set_yticks([0,5,10,15,20])
axs[1].yaxis.set_minor_locator(tck.AutoMinorLocator())
axs[1].xaxis.set_minor_locator(tck.AutoMinorLocator())
axs[1].set_title(r'$\beta=2$')
#axs[1].set_ylabel('Local Concentrations')
axs[1].set_xlabel('Distance z')
axs[1].tick_params(axis='both', which='major')
axs[1].tick_params(axis='both', which='minor')


axs[0].legend(title='With AMP removal',bbox_to_anchor=(3.35, 0.6),ncol=1,prop={'size': 14})
#axs[0].text(.60, .06, r'Hello', transform=axs[0].transAxes)

axs[1].legend(title=' No AMP removal',bbox_to_anchor=(2., 1.02),ncol=1,prop={'size': 14})

axs[0].xaxis.set_ticks_position('both')
axs[0].yaxis.set_ticks_position('both')

axs[1].xaxis.set_ticks_position('both')
axs[1].yaxis.set_ticks_position('both')


# set the spacing between subplots
plt.subplots_adjust(left=0.1,
                    bottom=0.1, 
                    right=0.9, 
                    top=0.9, 
                    wspace=0.27, 
                    hspace=1.2)
plt.show()
